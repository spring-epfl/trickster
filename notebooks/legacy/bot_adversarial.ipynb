# %%
# %load_ext  autoreload
# %autoreload 2

# %%
import sys
sys.path.append('..')

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import ast

from trickster.search import a_star_search, ida_star_search
from trickster.expansion import *

from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegressionCV
from sklearn.svm import SVC
from scipy.spatial import distance
from tqdm import tqdm_notebook, tqdm
from matplotlib import pyplot as plt

from defaultcontext import with_default_context
from profiled import Profiler, profiled

SEED = 2018
np.random.seed(SEED)

# %% [markdown]
# ## Load data
#
# We assume the target linear model will work on one-hot discretized features. This is a common practice, since a linear model can only capture linear relationship between response and a continuous feature. If the continuous feature, however, is quantized, the relationship captured can be non-linear.
#
# Therefore, we discretize and one-hot encode all features. We quantize the continuous features, like credit amount, age, etc., into 5 bins.

# %%
# Define helper functions.

def transform_collection(X_k):
    X_k = X_k.apply(lambda x: x.replace(';', ','))
    X_k = X_k.apply(ast.literal_eval)
    
    # Get the value of the maximum element in X_k.
    arg_max = np.max([item for sublist in X_k.values.tolist() for item in sublist])
    
    N = X_k.shape[0]
    X_k_transformed = np.zeros((N, arg_max+1), dtype='intc')
        
    for i in range(N):
        for item in X_k[i]:
            X_k_transformed[i, item] = 1

    return X_k_transformed

# %%
data_folder = 'data/twitter_bots/'

# Load data for humans.
df1 = pd.read_csv(data_folder + 'humans.1k.csv')
df1 = df1.drop('screen_name', axis=1) # remove screen_name column
df1 = df1.assign(is_bot=0)

# Load data for bots.
df2 = pd.read_csv(data_folder + 'bots.1k.csv')
df2 = df2.drop('screen_name', axis=1) # remove screen_name column
df2 = df2.assign(is_bot=1)

# Concatenate dataframes.
df = df1.append(df2, ignore_index=True)

# Perform feature quantization.
bins = 5
features = [
    'user_tweeted',
    'user_retweeted',
    'user_favourited',
    'user_replied',
    'likes_per_tweet',
    'retweets_per_tweet',
    'lists_per_user',
    'follower_friend_ratio',
    'tweet_frequency',
    'favourite_tweet_ratio',
    'age_of_account_in_days',
    'sources_count',
    'urls_count',
    'cdn_content_in_kb'
]

for feat in features:

    # Drop feature if there is only 1 distinct value.
    uniq_len = np.unique(df.loc[:, feat]).size
    if uniq_len == 1:
        df = df.drop(feat, axis=1)
        continue

    series = df.loc[:, feat]
    df.loc[:, feat] = pd.qcut(series, bins, duplicates='drop')
    
# Encode 'source_identity' field by setting '1's if source is present.
transformed = transform_collection(df.loc[:, 'source_identity'])
df = df.drop('source_identity', axis=1)

df['source_identity_other'] = transformed[:, 0]
df['source_identity_browser'] = transformed[:, 1]
df['source_identity_mobile'] = transformed[:, 2]
df['source_identity_osn'] = transformed[:, 3]
df['source_identity_automation'] = transformed[:, 4]
df['source_identity_marketing'] = transformed[:, 5]

# Perform one-hot encoding
df = pd.get_dummies(df)

# Separate features from targets
df_X = df.iloc[:, 1:]
df_y = df.iloc[:, 0]

print('Examples are represented as {}-dimensional vectors.'.format(df_X.shape[1]))
# Out:
# Examples are represented as 57-dimensional vectors.

# %%
# Convert to numpy
X = df_X.values.astype('intc')
y = df_y.values.astype('intc')
print('Shape of X: {}. Shape of y: {}.'.format(X.shape, y.shape))

# Split into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=SEED)
print('Number of training points: {}. Number of test points: {}.'.format(X_train.shape[0], X_test.shape[0]))
# Out:
# Shape of X: (1289, 57). Shape of y: (1289,).
# Number of training points: 1160. Number of test points: 129.

# %% [markdown]
# ## Fit the target model

# %% [markdown]
# Now we fit the target logistic regression model.

# %%
# Fit logistic regression and perform CV
from sklearn.metrics import make_scorer, accuracy_score, roc_auc_score, roc_curve, f1_score

Cs = np.arange(0.1, 2, 0.025)
class_weight = None # balanced or None
scoring = 'f1' # accuracy, f1 or roc_auc

clf = LogisticRegressionCV(
    Cs=Cs, 
    cv=5, 
    n_jobs=-1, 
    penalty='l2',
    scoring=scoring,
    class_weight=class_weight,
    random_state=SEED
)
clf.fit(X_train, y_train)

# Get best score and C value
mean_scores = np.mean(clf.scores_[1], axis=0)
best_idx = np.argmax(mean_scores)
best_score = mean_scores[best_idx]
best_C = clf.Cs_[best_idx]

constant_acc = 1 - sum(y_train) / len(y_train)
print('Training score for a constant model f(x) = 0 is: {:.2f}%.'.format(constant_acc*100))
print('Training accuracy is: {:.2f}%. Best C is: {:.4f}. Class weight: {}. Scoring: {}.'
      .format(clf.score(X_train, y_train)*100, best_C, class_weight, scoring))

# Training score for a constant model f(x) = 0 is: 61.38%.
# Training accuracy is: 88.02%. Best C is: 1.1750. Class weight: None. Scoring: f1.
# Out:
# Training score for a constant model f(x) = 0 is: 61.38%.
# Training accuracy is: 88.02%. Best C is: 1.1750. Class weight: None. Scoring: f1.

# %%
constant_acc = 1 - sum(y_test) / len(y_test)
print('Test score for a constant model f(x) = 0 is: {:.2f}%.'.format(constant_acc*100))
print('Test accuracy is: {:.2f}%.'.format(clf.score(X_test, y_test)*100))

# Test score for a constant model f(x) = 0 is: 61.24%.
# Test accuracy is: 90.70%.
# Out:
# Test score for a constant model f(x) = 0 is: 61.24%.
# Test accuracy is: 90.70%.

# %% [markdown]
# ## Perform adversarial examples search

# %% [markdown]
# Context-local counter we'll use for counting expanded graph nodes.

# %%
class CounterLimitExceeded(Exception):
    pass

@with_default_context(use_empty_init=True)
class Counter:
    limit = 5000
    
    def __init__(self):
        self.cnt = 0
        
    def increment(self):
        if Counter.limit is not None and self.cnt > Counter.limit:
            raise CounterLimitExceeded('>> Expansion counter limit {} reached.'.format(Counter.limit))
        self.cnt += 1
        
    def set_count(self, count):
        self.cnt = count
    
    def get_count(self):
        return self.cnt

# %% [markdown]
# Define transformable features and obtain their indexes in the feature vectors.

# %%
def index(xs, item):
    '''Can be used to get the index of the required substring within a string.'''
    idxs = [i for (i, x) in enumerate(xs) if item in x]
    return idxs

TRANSFORMABLE_FEATURES = [
    'user_tweeted',
    'user_retweeted',
    'user_favourited',
    'user_replied',
    'urls_count'
]

FEATURE_SET = []

for x in TRANSFORMABLE_FEATURES:
    FEATURE_SET.extend(index(df_X.columns, x))

# %% [markdown]
# Define expansions required for the expand_fn when searching for adversarial examples.

# %%
features = df_X.columns
EXPANSIONS = []

# Define expansion for user_tweeted feature.
idxs = index(features, 'user_tweeted')
EXPANSIONS.append((idxs, expand_quantized))

# Define expansion for user_retweeted feature.
idxs = index(features, 'user_retweeted')
EXPANSIONS.append((idxs, expand_quantized))

# Define expansion for user_favourited feature.
idxs = index(features, 'user_favourited')
EXPANSIONS.append((idxs, expand_quantized))

# Define expansion for user_replied feature.
idxs = index(features, 'user_replied')
EXPANSIONS.append((idxs, expand_quantized))

# Define expansion for urls_count feature.
idxs = index(features, 'urls_count')
EXPANSIONS.append((idxs, expand_quantized))

# %% [markdown]
# All the functions that need to be passed into the search, in the expected format.

# %%
@profiled
def find_adversarial(x, clf, search_fn, epsilon, expansions, target_confidence=0.5, 
                p_norm=1, q_norm=np.inf, **kwargs):
    """Transform an example until it is classified with target confidence."""
    
    def expand_fn(x, expansions, p_norm=1):
        """Expand x and compute the costs.
        Returns a list of tuples (child, cost)
        """
        # Increment the counter of expanded nodes.
        counter = Counter.get_default()
        counter.increment()
        
        children = expand(x, expansions)
        costs = [np.linalg.norm(x - c, ord=p_norm) for c in children]
        
        return list(zip(children, costs))

    def goal_fn(x, clf, target_confidence=0.5):
        """Tell whether the example has reached the goal."""
        return clf.predict_proba([x])[0, 1] <= target_confidence

    def heuristic_fn(x, clf, epsilon, q_norm=np.inf):
        """Distance to the decision boundary of a logistic regression classifier.
        By default the distance is w.r.t. L1 norm. This means that the denominator
        has to be in terms of the Holder dual norm (`q_norm`), so L-inf. I know,
        this interface is horrible.
        NOTE: The value has to be zero if the example is already on the target side
        of the boundary.
        """
        score = clf.decision_function([x])[0]
        if score <= 0:
            return 0.0
        h = np.abs(score) / np.linalg.norm(clf.coef_[0, list(FEATURE_SET)], ord=q_norm)
        
        return h * epsilon

    def hash_fn(x):
        """Hash function for examples."""
        return hash(x.tostring())

    if clf.predict_proba([x])[0, 1] <= target_confidence:
        raise Exception('Initial example is already classified as bening.')
        
    heuristic_fn = kwargs.get('heuristic_fn', heuristic_fn)

    return search_fn(
        start_node=x,
        expand_fn=lambda x: expand_fn(x, expansions, p_norm=p_norm),
        goal_fn=lambda x: goal_fn(x, clf, target_confidence),
        heuristic_fn=lambda x: heuristic_fn(x, clf, epsilon, q_norm=q_norm),
        hash_fn=hash_fn
    )

# %% [markdown]
# Main function that performs adversarial example search.

# %%
def find_adv_examples(X, search_fn, epsilon=1, target_confidence=0.5):
    """Find adversarial examples for a whole dataset"""
    
    # Dataframe for storing the results.
    results = pd.DataFrame(
        columns=['index', 'found', 'expansions', 'x', 'init_confidence', 
                 'x_adv', 'adv_confidence', 'real_cost', 'path_cost', 
                 'nodes_expanded', 'runtime']
    )
    
    # Indices of examples classified as bots.
    idxs, = np.where(clf.predict_proba(X)[:, 1] > target_confidence)
    
    for i, idx in enumerate(tqdm_notebook(idxs)):
        x = X[idx]
        
        # Instantiate a counter for expanded nodes, and a profiler.
        expanded_counter = Counter()
        per_example_profiler = Profiler()
        
        p_norm = 1
        q_norm = np.inf
        
        with expanded_counter.as_default(), per_example_profiler.as_default():
            try:
                x_adv, path_cost = find_adversarial(
                    x, 
                    clf, 
                    search_fn=search_fn,
                    epsilon=epsilon,
                    expansions=EXPANSIONS,
                    target_confidence=target_confidence,
                    p_norm=p_norm,
                    q_norm=q_norm,
                )
            except CounterLimitExceeded as e:
                print('>> WARN! {}'.format(e))
                continue

        nodes_expanded = expanded_counter.get_count()
        runtime = per_example_profiler.compute_stats()['find_adversarial']['tot']
        init_confidence = clf.predict_proba([x])[0, 1]
        
        # Record performed expansions and transformed features.
        expansions = [(x, y, z.__name__) for (x, (y, z)) in zip(TRANSFORMABLE_FEATURES, EXPANSIONS)]
        
        # If an adversarial example was not found, only record index, runtime, and 
        # the number of expanded nodes.        
        if x_adv is None:
            results.loc[i] = [idx, False, expansions, x, init_confidence, 
                              None, None, None, None, 
                              nodes_expanded, runtime]
        else:
            adv_confidence = clf.predict_proba([x_adv])[0, 1]
            real_cost = np.linalg.norm(x - x_adv, ord=p_norm)            
            results.loc[i] = [idx, True, expansions, x, init_confidence, 
                              x_adv, adv_confidence, real_cost, path_cost, 
                              nodes_expanded, runtime]

    return results

# %% [markdown]
# ## Run the experiments

# %% [markdown]
# Fix several target confidence levels (lower confidence - higher probability the account is a human, i.e. harder to evade).

# %%
confidence_levels = np.linspace(0.50, 0.05, 10)
confidence_levels
# Out:
# array([0.5 , 0.45, 0.4 , 0.35, 0.3 , 0.25, 0.2 , 0.15, 0.1 , 0.05])

# %%
results = []

for level in tqdm_notebook(confidence_levels):
    result = find_adv_examples(
        X, 
        a_star_search, 
        epsilon=1, 
        target_confidence=level
    )
    
    results.append(result)
# Out:
# HBox(children=(IntProgress(value=0, max=10), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=453), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=484), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=503), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=528), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=564), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=596), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=641), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=702), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=796), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=989), HTML(value='')))

# %% [markdown]
# Visualise changes that are required to transform initial example into an adversarial one.

# %%
def get_changes(results, columns):
    all_changes = []
    
    for idx, row in results.iterrows():
        x, x_adv, idx = row['x'], row['x_adv'], row['index']
        if x_adv is None:
            continue
            
        init = np.where((x != x_adv) & (x == 1))[0]
        diff = np.where((x != x_adv) & (x_adv == 1))[0]
        changes = ['{} -> {}'.format(x, y) for (x, y) in zip(columns[init], columns[diff])]
        all_changes.append((idx, changes))
        
    return all_changes

all_changes = get_changes(results[0], df_X.columns)

for idx, changes in all_changes:
    print('Adversarial example for sample at index {} was created with the following change(s):\n{}.\n'
          .format(idx, ',\n'.join(changes))
    )
# Out:
# Adversarial example for sample at index 3 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 39 was created with the following change(s):
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(2.0, 5.0].
#
# Adversarial example for sample at index 46 was created with the following change(s):
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 58 was created with the following change(s):
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 104 was created with the following change(s):
# user_tweeted_(7.0, 16.0] -> user_tweeted_(16.0, 766.0],
# urls_count_(5.0, 12.0] -> urls_count_(2.0, 5.0].
#
# Adversarial example for sample at index 146 was created with the following change(s):
# user_favourited_(12113.806, 211890.704] -> user_favourited_(1691.059, 4639.173],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 162 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 170 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 224 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 243 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 248 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(4.0, 9.0].
#
# Adversarial example for sample at index 264 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 272 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(4.0, 9.0].
#
# Adversarial example for sample at index 313 was created with the following change(s):
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 316 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(4.0, 9.0].
#
# Adversarial example for sample at index 317 was created with the following change(s):
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 333 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 334 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 336 was created with the following change(s):
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 393 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 394 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 421 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 423 was created with the following change(s):
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 435 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 463 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(1.0, 4.0],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 465 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 466 was created with the following change(s):
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 519 was created with the following change(s):
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 540 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 549 was created with the following change(s):
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 566 was created with the following change(s):
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 582 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(12113.806, 211890.704] -> user_favourited_(1691.059, 4639.173],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 589 was created with the following change(s):
# urls_count_(12.0, 806.0] -> urls_count_(2.0, 5.0].
#
# Adversarial example for sample at index 607 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 624 was created with the following change(s):
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 645 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 646 was created with the following change(s):
# user_favourited_(12113.806, 211890.704] -> user_favourited_(4639.173, 12113.806].
#
# Adversarial example for sample at index 675 was created with the following change(s):
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 695 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(4.0, 9.0],
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 700 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(4.0, 9.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 713 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 717 was created with the following change(s):
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 732 was created with the following change(s):
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 736 was created with the following change(s):
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 742 was created with the following change(s):
# user_tweeted_(16.0, 766.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 779 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(12113.806, 211890.704] -> user_favourited_(4639.173, 12113.806].
#
# Adversarial example for sample at index 780 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0].
#
# Adversarial example for sample at index 782 was created with the following change(s):
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0].
#
# Adversarial example for sample at index 783 was created with the following change(s):
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# user_replied_(1.0, 2.0] -> user_replied_(2.0, 6.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 788 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 791 was created with the following change(s):
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 793 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 794 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(12113.806, 211890.704] -> user_favourited_(1691.059, 4639.173],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 796 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 798 was created with the following change(s):
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 799 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 800 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 801 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 804 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 807 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 809 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 812 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 813 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 814 was created with the following change(s):
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 819 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 822 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 823 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 827 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 828 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 830 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 833 was created with the following change(s):
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 839 was created with the following change(s):
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 841 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(14.0, 885.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 842 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 844 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0].
#
# Adversarial example for sample at index 846 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0].
#
# Adversarial example for sample at index 849 was created with the following change(s):
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 850 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0].
#
# Adversarial example for sample at index 852 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(4.0, 9.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 853 was created with the following change(s):
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 854 was created with the following change(s):
# urls_count_(12.0, 806.0] -> urls_count_(2.0, 5.0].
#
# Adversarial example for sample at index 855 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 856 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(4.0, 9.0].
#
# Adversarial example for sample at index 858 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0].
#
# Adversarial example for sample at index 859 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 860 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 861 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 862 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 864 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0].
#
# Adversarial example for sample at index 867 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 868 was created with the following change(s):
# user_tweeted_(-0.001, 1.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(9.0, 885.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(12113.806, 211890.704] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 873 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 874 was created with the following change(s):
# user_tweeted_(7.0, 16.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(9.0, 885.0] -> user_retweeted_(4.0, 9.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 878 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 880 was created with the following change(s):
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 881 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 886 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 887 was created with the following change(s):
# user_tweeted_(-0.001, 1.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 888 was created with the following change(s):
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 891 was created with the following change(s):
# user_tweeted_(7.0, 16.0] -> user_tweeted_(16.0, 766.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 893 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(2.0, 6.0] -> user_replied_(14.0, 885.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 896 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 900 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 907 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(4.0, 9.0],
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 909 was created with the following change(s):
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 910 was created with the following change(s):
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 911 was created with the following change(s):
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 913 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(1.0, 4.0],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 915 was created with the following change(s):
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 919 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(4.0, 9.0],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 920 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 921 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 923 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 928 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 930 was created with the following change(s):
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 931 was created with the following change(s):
# user_tweeted_(-0.001, 1.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(9.0, 885.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 932 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 934 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 935 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 936 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 939 was created with the following change(s):
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 940 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0].
#
# Adversarial example for sample at index 941 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 942 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 944 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 945 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 950 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0].
#
# Adversarial example for sample at index 951 was created with the following change(s):
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 952 was created with the following change(s):
# user_tweeted_(-0.001, 1.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 953 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 956 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 957 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 958 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 959 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 960 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(1.0, 2.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 970 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 971 was created with the following change(s):
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 974 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 975 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 976 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 977 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0].
#
# Adversarial example for sample at index 979 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 980 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 982 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 983 was created with the following change(s):
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 986 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 988 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 989 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 992 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 993 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 994 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 995 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 997 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 999 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 1010 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 1015 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1020 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 1026 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 1027 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1029 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1030 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 1036 was created with the following change(s):
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 1039 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1043 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(1.0, 4.0],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1044 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1045 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 1048 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 1049 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1050 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1051 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(4.0, 9.0].
#
# Adversarial example for sample at index 1055 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1056 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0].
#
# Adversarial example for sample at index 1062 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 1064 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(12113.806, 211890.704] -> user_favourited_(1691.059, 4639.173],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1067 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 1069 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(12113.806, 211890.704] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(14.0, 885.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1072 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 1075 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 1077 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 1079 was created with the following change(s):
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1080 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1084 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 1086 was created with the following change(s):
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1088 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1096 was created with the following change(s):
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1097 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0].
#
# Adversarial example for sample at index 1098 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(12113.806, 211890.704] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1102 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1103 was created with the following change(s):
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1107 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(1.0, 4.0],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1108 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 1109 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 1110 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1117 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 1118 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_favourited_(12113.806, 211890.704] -> user_favourited_(1691.059, 4639.173],
# user_replied_(2.0, 6.0] -> user_replied_(14.0, 885.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1121 was created with the following change(s):
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 1122 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1126 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1127 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_replied_(1.0, 2.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 1136 was created with the following change(s):
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 1138 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1141 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(4.0, 9.0],
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 1144 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(1.0, 4.0],
# urls_count_(12.0, 806.0] -> urls_count_(5.0, 12.0].
#
# Adversarial example for sample at index 1148 was created with the following change(s):
# user_tweeted_(16.0, 766.0] -> user_tweeted_(4.0, 7.0],
# user_favourited_(12113.806, 211890.704] -> user_favourited_(1691.059, 4639.173],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1149 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0].
#
# Adversarial example for sample at index 1156 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_favourited_(12113.806, 211890.704] -> user_favourited_(4639.173, 12113.806],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1159 was created with the following change(s):
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1160 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 1161 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1162 was created with the following change(s):
# user_tweeted_(7.0, 16.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1163 was created with the following change(s):
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 1164 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(2.0, 6.0] -> user_replied_(14.0, 885.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1178 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 1180 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1182 was created with the following change(s):
# user_tweeted_(-0.001, 1.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_replied_(-0.001, 1.0] -> user_replied_(14.0, 885.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1183 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 1188 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(14.0, 885.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1189 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1190 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 1191 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 1192 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 1194 was created with the following change(s):
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1195 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1196 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1198 was created with the following change(s):
# user_tweeted_(-0.001, 1.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1199 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 1204 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 1208 was created with the following change(s):
# user_favourited_(12113.806, 211890.704] -> user_favourited_(1691.059, 4639.173],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1209 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 1210 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 1213 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1214 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 1215 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 1217 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1218 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1220 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 1224 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(4.0, 9.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1225 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 1226 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0].
#
# Adversarial example for sample at index 1228 was created with the following change(s):
# user_tweeted_(7.0, 16.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1229 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1231 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0].
#
# Adversarial example for sample at index 1232 was created with the following change(s):
# user_tweeted_(16.0, 766.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1234 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1235 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1236 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1237 was created with the following change(s):
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1238 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 1239 was created with the following change(s):
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1241 was created with the following change(s):
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(1.0, 2.0] -> user_replied_(2.0, 6.0].
#
# Adversarial example for sample at index 1245 was created with the following change(s):
# user_tweeted_(-0.001, 1.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(14.0, 885.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1246 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1247 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0].
#
# Adversarial example for sample at index 1251 was created with the following change(s):
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1252 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(12113.806, 211890.704] -> user_favourited_(1691.059, 4639.173],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0].
#
# Adversarial example for sample at index 1254 was created with the following change(s):
# user_tweeted_(16.0, 766.0] -> user_tweeted_(4.0, 7.0],
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1255 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0].
#
# Adversarial example for sample at index 1258 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 1261 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# urls_count_(12.0, 806.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1265 was created with the following change(s):
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 1271 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(207.8, 1691.059] -> user_favourited_(1691.059, 4639.173],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1272 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173].
#
# Adversarial example for sample at index 1274 was created with the following change(s):
# user_retweeted_(9.0, 885.0] -> user_retweeted_(4.0, 9.0].
#
# Adversarial example for sample at index 1277 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(14.0, 885.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1279 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059],
# urls_count_(2.0, 5.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1280 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(207.8, 1691.059].
#
# Adversarial example for sample at index 1281 was created with the following change(s):
# user_favourited_(12113.806, 211890.704] -> user_favourited_(1691.059, 4639.173],
# user_replied_(6.0, 14.0] -> user_replied_(14.0, 885.0],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1283 was created with the following change(s):
# user_tweeted_(1.0, 4.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173],
# user_replied_(-0.001, 1.0] -> user_replied_(1.0, 2.0].
#
# Adversarial example for sample at index 1284 was created with the following change(s):
# user_tweeted_(7.0, 16.0] -> user_tweeted_(4.0, 7.0],
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(4639.173, 12113.806] -> user_favourited_(1691.059, 4639.173],
# user_replied_(2.0, 6.0] -> user_replied_(14.0, 885.0],
# urls_count_(-0.001, 1.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1285 was created with the following change(s):
# user_retweeted_(4.0, 9.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(12113.806, 211890.704] -> user_favourited_(1691.059, 4639.173],
# urls_count_(5.0, 12.0] -> urls_count_(1.0, 2.0].
#
# Adversarial example for sample at index 1287 was created with the following change(s):
# user_retweeted_(-0.001, 1.0] -> user_retweeted_(1.0, 4.0],
# user_favourited_(-0.001, 207.8] -> user_favourited_(1691.059, 4639.173].

# %% [markdown]
# ### Plots

# %% [markdown]
# Compare A\* search to IDA\* search to BFS.

# %%
def get_expanded_nodes_stats(X, target_confidence=0.5, p_norm=1, q_norm=np.inf):

    # Indices of examples classified as bots.
    idxs, = np.where(clf.predict_proba(X)[:, 1] > target_confidence)
    counts = []

    for i, idx in enumerate(tqdm_notebook(idxs)):
        
        x = X[idx]
        
        with Counter().as_default() as cnt_astar:
            try: 
                x_adv_1, _ = find_adversarial(x, clf, search_fn=a_star_search, epsilon=1, expansions=EXPANSIONS, 
                    target_confidence=target_confidence, p_norm=p_norm, q_norm=q_norm)       
            except CounterLimitExceeded:
                cnt_astar = Counter()
                cnt_astar.set_count(Counter.limit)
            
        with Counter().as_default() as cnt_bfs:
            try:
                heuristic_fn = lambda x, clf, epsilon, q_norm: 0 
                x_adv_2, _ = find_adversarial(x, clf, search_fn=a_star_search, epsilon=1, expansions=EXPANSIONS, 
                    target_confidence=target_confidence, p_norm=p_norm, q_norm=q_norm, heuristic_fn=heuristic_fn)       
            except CounterLimitExceeded:
                cnt_bfs = Counter()
                cnt_bfs.set_count(Counter.limit)
                
        if x_adv_1 is None and x_adv_2 is None:
            continue
        
        counts.append([cnt_astar.get_count(), cnt_bfs.get_count()])
        
    return pd.DataFrame(counts, columns=['A*', 'BFS'])

# %%
p_norms = [1, 2, np.inf]
q_norms = [np.inf, 2, 1]

stats = []

for p_norm, q_norm in tqdm_notebook(zip(p_norms, q_norms), total=len(p_norms)):
    
    search_fns_stats = get_expanded_nodes_stats(X, target_confidence=0.5, p_norm=p_norm, q_norm=q_norm)

    # Obtain indexes that would sort the BFS expansions array.
    idxs = np.argsort(search_fns_stats['BFS'].values)
    bfs_stats = search_fns_stats['BFS'].values[idxs]
    astar_stats = search_fns_stats['A*'].values[idxs]
    
    improvement = ((bfs_stats - astar_stats) / astar_stats) * 100
    
    stats.append({
        'stats': search_fns_stats,
        'improvement': improvement,
        'p_norm': p_norm,
        'q_norm': q_norm
    })

    # Display the "A* search vs BFS search" plot.
    plt.figure(figsize=(12,4))
    plt.title('A* Search vs BFS search (p-norm: {}, q-norm: {})'.format(p_norm, q_norm))
    plt.plot(astar_stats, color='red', label='A* search')
    plt.plot(bfs_stats, color='blue', label='BFS search')
    plt.grid(True)
    plt.xlabel('Examples (sorted by number of BFS expansions)', fontsize=12)
    plt.ylabel('Expansions', fontsize=12)
    plt.legend(loc='best', fontsize=11)
    plt.show()

    # Display the "A* over BFS search improvement" plot.

    plt.figure(figsize=(12,4))
    plt.plot(improvement, color='green')
    plt.grid(True)
    plt.xlabel('Examples (sorted by number of BFS expansions)', fontsize=12)
    plt.ylabel('A* improvement over BFS (%)', fontsize=12)
    plt.show()
    
    print('Average A* improvement over BFS: {:.2f}%.'.format(np.sum(improvement) / len(improvement)))
# Out:
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=453), HTML(value='')))
# Average A* improvement over BFS: 41.36%.
# HBox(children=(IntProgress(value=0, max=453), HTML(value='')))
# Average A* improvement over BFS: 58.13%.
# HBox(children=(IntProgress(value=0, max=453), HTML(value='')))
# Average A* improvement over BFS: 0.00%.

# %% [markdown]
# Success rates for crafting adversarial examples, and average confidence of these.

# %%
def plot_confidence(results):
    success_prop = [result['found'].mean() for result in results]
    avg_confidence = [result['init_confidence'].mean() for result in results]
    
    fig, ax = plt.subplots()
    ax.set_xticks(confidence_levels)
    ax.plot(confidence_levels, success_prop,
            label='Success proportion')
    ax.plot(confidence_levels, avg_confidence,
            label='Avg confidence of adversarial examples')
    ax.plot(confidence_levels, confidence_levels,
            linestyle='dashed', color='gray', label='Baseline confidence')
    ax.set_xlabel('Target confidence')
    ax.set_ylabel('Success rates for crafting adversarial examples')
    plt.title('')
    plt.legend()
    plt.show()

# %%
plot_confidence(results)

# %% [markdown]
# Number of expanded nodes.

# %%
avg_expanded = pd.Series(
    [np.mean(result['nodes_expanded'][result['found']])
     for result in results])
sigma_expanded = pd.Series(
    [np.std(result['nodes_expanded'][result['found']])
     for result in results])

avg_runtime = pd.Series(
    [np.mean(result['runtime'][result['found']])
     for result in results])

fig, ax = plt.subplots()
avg_expanded.plot(label='Number of expanded nodes', ax=ax)
ax.fill_between(range(len(confidence_levels)),
                avg_expanded - 2 * sigma_expanded,
                avg_expanded + 2 * sigma_expanded, alpha=.2)
ax.set_xticks(range(len(confidence_levels)))
ax.set_xticklabels(['%2.2f' % level for level in confidence_levels])
ax.set_xlim(0, len(confidence_levels) - 1)
ax.set_xlabel('Target confidence')
ax.set_ylabel('Number of expanded nodes')

avg_runtime.plot(secondary_y=True, label='Avg runtime')
plt.show()
